# %%
import pandas as pd

# %%
df=pd.read_csv("ohio_valley_turnout.csv")

# %%
(df["turnout_pct_diff"] > 0).sum()
# Out:
# 224

# %%
224 *100/263
# Out:
# 85.17110266159696

# %%
df[df["voter_turnout_pct_2020"] < 50]
# Out:
#         County state  Trump_2020  Biden_2020  total_votes_2020  \
# 6         Bell    KY      8139.0      1789.0           10042.0
# 23   Christian    KY     15060.0      8282.0           23825.0
# 25        Clay    KY      6003.0       430.0            6498.0
# 37      Fulton    KY      1605.0       791.0            2421.0
# 76      Martin    KY      3496.0       402.0            3929.0
# 146   McDowell    WV      5125.0      1323.0            6494.0
# 174    Wyoming    WV      7254.0      1149.0            8485.0
#
#      reg_voters_2020  ballots_cast_2020  voter_turnout_pct_2020  \
# 6            21276.0            10102.0                   47.48
# 23           56018.0            23940.0                   42.74
# 25           14727.0             6602.0                   44.83
# 37            5613.0             2429.0                   43.27
# 76            8305.0             3965.0                   47.74
# 146          15529.0             6556.0                   42.22
# ...

# %%
df.sort_values("turnout_pct_diff", ascending=False)
# Out:
#          County state  Trump_2020  Biden_2020  total_votes_2020  \
# 126     Calhoun    WV      2346.0       563.0            2948.0
# 133   Hampshire    WV      7829.0      1919.0            9858.0
# 151      Monroe    WV      5012.0      1330.0            6417.0
# 162     Ritchie    WV      3637.0       585.0            4269.0
# 132  Greenbrier    WV     10898.0      4641.0           15807.0
# ..          ...   ...         ...         ...               ...
# 179      Athens    OH     10386.0     14047.0           24809.0
# 105      Shelby    KY     14631.0      7520.0           22517.0
# 78    McCracken    KY     21399.0     10582.0           32453.0
# 33      Fayette    KY     57132.0     85211.0          145373.0
# 30     Edmonson    KY      4265.0       682.0            5004.0
#
#      reg_voters_2020  ballots_cast_2020  voter_turnout_pct_2020  \
# 126           4768.0             2977.0                   62.44
# 133          14039.0             9932.0                   70.75
# ...

# %%
df[df["turnout_pct_diff"] >10]
# Out:
#          County state  Trump_2020  Biden_2020  total_votes_2020  \
# 126     Calhoun    WV      2346.0       563.0            2948.0
# 132  Greenbrier    WV     10898.0      4641.0           15807.0
# 133   Hampshire    WV      7829.0      1919.0            9858.0
# 137     Jackson    WV     10025.0      3197.0           13429.0
# 151      Monroe    WV      5012.0      1330.0            6417.0
# 162     Ritchie    WV      3637.0       585.0            4269.0
# 163       Roane    WV      4199.0      1451.0            5745.0
# 170     Webster    WV      2737.0       608.0            3378.0
# 171      Wetzel    WV      4933.0      1529.0            6596.0
#
#      reg_voters_2020  ballots_cast_2020  voter_turnout_pct_2020  \
# 126           4768.0             2977.0                   62.44
# 132          23761.0            15928.0                   67.03
# 133          14039.0             9932.0                   70.75
# 137          20079.0            13590.0                   67.68
# ...
