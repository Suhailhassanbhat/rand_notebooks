# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

import re
import camelot

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # Goals
# 1. Get daily cases, deaths, total cases, deaths and 18 and under cases from table 1
# 2. Get Testing Data from one of the tables on first page

# %%
# read links here
links_df=pd.read_csv("../url_scraper/ky_daily_covid_report_links.csv")
links_df.date=pd.to_datetime(links_df.date)
links_df = links_df.sort_values('date', ascending=False).reset_index(drop=True)
links_df[:228]
# Out:
#           date                                               link
# 0   2021-07-30  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 1   2021-07-29  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 2   2021-07-28  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 3   2021-07-27  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 4   2021-07-26  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# ..         ...                                                ...
# 223 2020-12-19  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 224 2020-12-18  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 225 2020-12-17  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 226 2020-12-16  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
# 227 2020-12-15  https://chfs.ky.gov/cvdaily/COVID19DailyReport...
#
# [228 rows x 2 columns]

# %%
# ky_url="https://govstatus.egov.com/kycovid19"
ky_daily_report="https://chfs.ky.gov/agencies/dph/covid19/COVID19DailyReport.pdf"

# %%
tables=camelot.read_pdf(ky_daily_report, flavor='lattice', pages='1,2')

# %% [markdown]
# ## CASES AND DEATHS

# %%
# cases_summary=tables[0].df.T
# new_header=cases_summary.iloc[0]
# cases_summary=cases_summary[1:]
# cases_summary.columns=new_header
# cases_summary = cases_summary.reset_index(drop=True)
# cases_sum = cases_summary.drop(cases_summary.columns[0], axis=1)
# category =[]
# category.append(cases_summary.columns[0].split()[1])
# category.append(cases_summary.columns[0].split()[2])
# category.append(cases_summary.columns[0].split()[3])
# categories=pd.DataFrame(category)
# categories.columns=['type']
# cases = categories.join(cases_sum)
# #extract today's date and convert it to datetime
# cases['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# cases.date=pd.to_datetime(cases.date)
# #remove comma separator
# cases=cases.replace(',', '', regex=True)
# #convert to integers in one go
# cases[['Cases', 'Deaths', 'New Cases', 'New Cases 18 and Under',
#        'Total New Deaths']]= cases[['Cases', 'Deaths', 'New Cases', 'New Cases 18 and Under',
#        'Total New Deaths']].apply(pd.to_numeric)
# cases

# %%
# pd.DataFrame.from_dict(cases.to_dict("dict"))

# %% [markdown]
# ## Testing numbers

# %%
# test_table = tables[4].df.iloc[1].str.split(n=8, expand=True)
# test_table.columns = ["total_test", 'total_pcr_tests', 'total_serology_tests'
#                       , 'total_antigen_tests','total_positive_tests'
#                       , 'total_pcr_positive', 'total_serology_positive'
#                       , 'total_antigen_positive']
# test_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# test_table.date=pd.to_datetime(test_table.date)
# test_table=test_table.replace(",", "", regex=True)
# test_table

# %% [markdown]
# ## CASES AND DEATHS BY RACE

# %%
# race_table = tables[1].df[1:].reset_index(drop=True)
# race_table.columns=["cases", "case_percent", 'race', "death_percent", "deaths"]
# race_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# race_table.date=pd.to_datetime(race_table.date)
# race_table=race_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# race_table

# %% [markdown]
# ## CASES AND DEATHS BY ETHNICITY

# %%
# ethnicity_table=tables[2].df[1:].reset_index(drop=True)
# ethnicity_table=ethnicity_table[0].str.split(n=5, expand=True)
# ethnicity_table.columns=["cases", "case_percent", 'race', "death_percent", "deaths"]
# ethnicity_table=ethnicity_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# ethnicity_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# ethnicity_table.date=pd.to_datetime(ethnicity_table.date)
# ethnicity_table

# %% [markdown]
# ## AGE BREAKUP

# %%
# age_table =tables[3].df[1:].reset_index(drop=True)
# age_table.columns=["cases", "case_pct", "age_group", "death_pct", "deaths"]
# age_table=age_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# age_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# age_table.date=pd.to_datetime(age_table.date)
# age_table

# %% [markdown]
# ## Total Hospitalized since last March

# %%
# hosp_table=tables[5].df[0].str.split(n=3,expand=True)
# hosp_table.columns=hosp_table.iloc[0]
# hosp_table =hosp_table[1:].reset_index(drop=True)
# hosp_table=hosp_table.drop(['Outcomes'], axis=1)
# hosp_table.columns.values[0] = 'total'
# hosp_table.columns.values[1] = 'cases'
# hosp_table.columns.values[2] = 'percent'
# hosp_table=hosp_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# hosp_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# hosp_table.date=pd.to_datetime(hosp_table.date)
# hosp_table

# %% [markdown]
# ## Currrent capacity

# %%
# capacity_table = tables[6].df[1:].reset_index(drop=True)
# capacity_table.columns = ["total_beds", 'occupied', 'available', 'occupancy']
# capacity_table=capacity_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# capacity_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# capacity_table.date=pd.to_datetime(capacity_table.date)
# capacity_table

# %% [markdown]
# ## Current hospitalized, ICU, Ventilators

# %%
# cHosp_table=tables[7].df[1:].reset_index(drop=True)
# cHosp_table.columns=["type", 'daily_total']
# cHosp_table=cHosp_table.replace(",", "", regex=True).replace( "%", "", regex=True)
# cHosp_table['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# cHosp_table.date=pd.to_datetime(cHosp_table.date)
# cHosp_table

# %% [markdown]
# ## hopsital occupancy by region

# %%
# region_occupancy=tables[8].df[1:].reset_index(drop=True)
# region_occupancy.columns=['region','covid_inpatient', 'covid_icu', 'covid_on_ventilators',
#                          'pct_inpatient_used_for_covid', 'pct_icus_for_covid', 'pct_vents_for_covid',
#                          'pct_inpatient_used', 'pct_icus_used', 'pct_vents_used']

# region_occupancy=region_occupancy.replace(",", "", regex=True).replace( "%", "", regex=True)
# region_occupancy['date'] = pd.to_datetime("today").strftime("%Y-%m-%d")
# region_occupancy.date=pd.to_datetime(region_occupancy.date)
# region_occupancy

# %% [markdown]
# ## Scraping cases data going back to March 2020

# %%
## scraping cases and deaths from 52
# cases_list=[]
# for link in links_df[:52].link:
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1,2')
#     cases_summary=tables[0].df.T
#     new_header=cases_summary.iloc[0]
#     cases_summary=cases_summary[1:]
#     cases_summary.columns=new_header
#     cases_summary = cases_summary.reset_index(drop=True)
#     cases_sum = cases_summary.drop(cases_summary.columns[0], axis=1)
#     category =[]
#     category.append(cases_summary.columns[0].split()[1])
#     category.append(cases_summary.columns[0].split()[2])
#     category.append(cases_summary.columns[0].split()[3])
#     categories=pd.DataFrame(category)
#     categories.columns=['type']
#     cases = categories.join(cases_sum)
#     cases=cases.replace(',', '', regex=True)
#     cases['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases['date'] = pd.to_datetime(cases['date'], format='%m%d%y')
#     cases_list.append(cases)
# data_june_2021=pd.concat(cases_list)
## data_june_2021.reset_index(drop=True).to_csv("covid_june_2_on.csv", index=False)

# %%
## scraping 75 links
# cases_list=[]
# for link in links_df[52:127].link:
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1,2')
#     cases_summary=tables[0].df.T
#     new_header=cases_summary.iloc[0]
#     cases_summary=cases_summary[1:]
#     cases_summary.columns=new_header
#     cases_summary = cases_summary.reset_index(drop=True)
#     cases_sum = cases_summary.drop(cases_summary.columns[0], axis=1)
#     category =[]
#     category.append(cases_summary.columns[0].split()[1])
#     category.append(cases_summary.columns[0].split()[2])
#     category.append(cases_summary.columns[0].split()[3])
#     categories=pd.DataFrame(category)
#     categories.columns=['type']
#     cases = categories.join(cases_sum)
#     cases=cases.replace(',', '', regex=True)
#     cases['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
# #     cases['date'] = pd.to_datetime(cases['date'], format='%m%d%y')
#     cases_list.append(cases)
# data_march19_june01=pd.concat(cases_list)
# data_march19_june01.date=data_march19_june01.date.astype(int).replace(
#     [4092021, 4102021, 4112021, 4122021], [40921, 41021, 41121, 41221])
# data_march19_june01['date']=pd.to_datetime(data_march19_june01['date'], format='%m%d%y')
# data_march19_june01=data_march19_june01.replace(".", "")
## data_march19_june01.reset_index(drop=True).to_csv("covid_march19_june01.csv", index=False)

# %%
## scraping 94 links; total 52+75+94 = 221 links
# cases_list=[]
# for link in links_df[127:221].link:
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1,2')
#     cases_summary=tables[0].df.T
#     new_header=cases_summary.iloc[0]
#     cases_summary=cases_summary[1:]
#     cases_summary.columns=new_header
#     cases_summary = cases_summary.reset_index(drop=True)
#     cases_sum = cases_summary.drop(cases_summary.columns[0], axis=1)
#     category =[]
#     category.append(cases_summary.columns[0].split()[1])
#     category.append(cases_summary.columns[0].split()[2])
#     category.append(cases_summary.columns[0].split()[3])
#     categories=pd.DataFrame(category)
#     categories.columns=['type']
#     cases = categories.join(cases_sum)
#     cases=cases.replace(',', '', regex=True)
#     cases['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
# #     cases['date'] = pd.to_datetime(cases['date'], format='%m%d%y')
#     cases_list.append(cases)
# data_dec15_mar18=pd.concat(cases_list)
# data_dec15_mar18.date=data_dec15_mar18.date.replace(['03082021', '03042021', '03032021', '03012021', '02252021', '02022021', '10421',
#  '1231', '1230','1229', '1228', '1227', '1226', '1225', '1224', '1223', '1222',
#  '1221', '1220', '1219', '1218', '1217', '1216', '1215'],
# ['030821', '030421', '030321', '030121', '022521', '020221', '010421',
#  '123120', '123020','122920', '122820', '122720', '122620', '122520', '122420', '122320', 
#  '122220', '122120', '122020', '121920', '121820', '121720', '121620', '121520'])

# data_dec15_mar18.date = pd.to_datetime(data_dec15_mar18.date, format='%m%d%y')

# data_dec15_mar18

# # data.reset_index(drop=True).to_csv("covid_dec15_mar18.csv", index=False)

# %%
# cases_list=[]
# for link in links_df[230:300].link:
#     cases_dict ={}
#     tables=camelot.read_pdf(link, flavor='stream', pages='1')
#     table=tables[0].df
#     tot_table=table[[0,1]]
#     cases_dict["tot_cases"]=tot_table[tot_table[0].str.contains("Total Cases")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_cases_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_cases_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_deaths"]=tot_table[tot_table[0].str.contains("Total Deaths")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_deaths_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict["tot_deaths_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     new_table=table[[2,3]]
#     cases_dict["new_cases"]=new_table[new_table[2].str.contains(
#         "New Cases")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict["new_deaths"]=new_table[new_table[2].str.contains(
#         "New Deaths")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases_list.append(cases_dict)
    
# df_12050927=pd.DataFrame(cases_list)
# # df_12050927.to_csv("data_12050927.csv", index=False)

# %%
# cases_list=[]
# for link in links_df[221:223].link:
#     cases_dict ={}
#     tables=camelot.read_pdf(link, flavor='stream', pages='1')
#     table=tables[0].df
#     tot_table=table[[0,1]]
#     cases_dict["tot_cases"]=tot_table[tot_table[0].str.contains("Total Cases")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_cases_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_cases_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_deaths"]=tot_table[tot_table[0].str.contains("Total Deaths")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_deaths_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict["tot_deaths_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     new_table=table[[2,3]]
#     cases_dict["new_cases"]=new_table[new_table[2].str.contains(
#         "New Cases")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict["new_deaths"]=new_table[new_table[2].str.contains(
#         "New Deaths")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases_list.append(cases_dict)
    
# df_12141213=pd.DataFrame(cases_list)
# # df_12141213.to_csv("data_12141213.csv", index=False)

# %%
# cases_list=[]
# for link in links_df[228:230].link:
#     cases_dict ={}
#     tables=camelot.read_pdf(link, flavor='stream', pages='1')
#     table=tables[0].df
#     tot_table=table[[0,1]]
#     cases_dict["tot_cases"]=tot_table[tot_table[0].str.contains("Total Cases")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_cases_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_cases_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_deaths"]=tot_table[tot_table[0].str.contains("Total Deaths")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_deaths_conf"]=tot_table[tot_table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict["tot_deaths_prob"]=tot_table[tot_table[0].str.contains("Probable")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     new_table=table[[2,3]]
#     cases_dict["new_cases"]=new_table[new_table[2].str.contains(
#         "New Cases")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict["new_deaths"]=new_table[new_table[2].str.contains(
#         "New Deaths")].reset_index(drop=True).iloc[0].reset_index(drop=True)[1].replace(",", "")
#     cases_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases_list.append(cases_dict)
    
# df_12071206=pd.DataFrame(cases_list)
# # df_12071206.to_csv("data_12071206.csv", index=False)

# %%
# cases_list=[]
# for link in links_df[223:228].link:
#     cases_dict ={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     table=tables[0].df
#     cases_dict["tot_cases"]=table[table[0].str.contains("Total Cases")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_cases_conf"]=table[table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_cases_prob"]=table[table[0].str.contains("Probable")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_deaths"]=table[table[0].str.contains("Total Deaths")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_deaths_conf"]=table[table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict["tot_deaths_prob"]=table[table[0].str.contains("Probable")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases_list.append(cases_dict)

# df_12121208= pd.DataFrame(cases_list)
# df_12121208=df_12121208.join(pd.DataFrame([{"new_cases":3558,"new_deaths":24},
# {"new_cases":3691,"new_deaths":22},
# {"new_cases":4324,"new_deaths":28},
# {"new_cases":3481,"new_deaths":16},
# {"new_cases":3114,"new_deaths":20}]))
# # df_12121208.to_csv('data_12121208.csv', index=False)

# %%
# cases_list=[]
# for link in links_df[300:418].link:
#     cases_dict ={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     table=tables[0].df
#     cases_dict["tot_cases"]=table[table[0].str.contains("Total Cases")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_cases_conf"]=table[table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_cases_prob"]=table[table[0].str.contains("Probable")].reset_index(drop=True).iloc[0][1].replace(",", "")
#     cases_dict["tot_deaths"]=table[table[0].str.contains("Total Deaths")][1].reset_index(drop=True)[0].replace(",", "")
#     cases_dict["tot_deaths_conf"]=table[table[0].str.contains("Confirmed")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict["tot_deaths_prob"]=table[table[0].str.contains("Probable")].reset_index(drop=True).iloc[1][1].replace(",", "")
#     cases_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     cases_list.append(cases_dict)
# df_06010927=pd.DataFrame(cases_list)
# df_06010927=df_06010927.sort_values("date")
# df_06010927['new_cases']=df_06010927.tot_cases.astype(int).diff().fillna(214)
# df_06010927['new_deaths']=df_06010927.tot_deaths.astype(int).diff().fillna(5)
# df_06010927=df_06010927.sort_values("date", ascending=False)
# # df_06010927.to_csv("data_06010926.csv", index=False)

# %% [markdown]
# # Scraping historical testing data

# %%
# test_list=[]
# links=links_df.link.iloc[:100]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,121,580,60'], split_text=True)
#     # tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,151,580,60'], split_text=True)

#     test_table=tables[0].df.iloc[3].str.replace(",", "")
#     test_dict['date']=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")+"20" 
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
#     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['total_positive_tests']=test_table[4]
#     test_dict['total_pcr_positive']=test_table[5]
#     test_dict['total_serology_positive']=test_table[6]
#     test_dict['total_antigen_positive']=test_table[7]

#     test_list.append(test_dict)
# df_1230_0707=pd.DataFrame(test_list)
# df_1230_0707 = df_1230_0707[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# test_list=[]
# links=links_df.link.iloc[100:166]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,121,580,60'], split_text=True)
#     # tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,151,580,60'], split_text=True)

#     test_table=tables[0].df.iloc[3].str.replace(",", "")
#     test_dict['date']=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
#     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['total_positive_tests']=test_table[4]
#     test_dict['total_pcr_positive']=test_table[5]
#     test_dict['total_serology_positive']=test_table[6]
#     test_dict['total_antigen_positive']=test_table[7]

#     test_list.append(test_dict)
# df_165=pd.DataFrame(test_list)
# df_165 = df_165[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# # pull data from 166 and 170 because there format changes:
# test_list=[]
# # for link in 
# for link in (links_df.link.iloc[166], links_df.link.iloc[170]):
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     tables
#     test_table = tables[4].df.iloc[1].str.split(n=8, expand=True)
# #     print(test_table.index)
# #     print(test_table)
#     test_table.columns = ["tot_tests", 'total_pcr_tests', 'total_serology_tests'
#                           , 'total_antigen_tests','total_positive_tests'
#                           , 'total_pcr_positive', 'total_serology_positive'
#                           , 'total_antigen_positive']
#     test_table['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")

# #     test_table.date=pd.to_datetime(test_table.date)
#     test_table=test_table.replace(",", "", regex=True)
#     test_list.append(test_table)
# df_166_170=pd.concat(test_list).reset_index(drop=True)
# df_166_170 = df_166_170[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# # pull data from 166 and 170 because there format changes:
# test_list=[]
# # for link in 
# links=links_df.link.iloc[167:170]
# for link in links:
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     tables
#     test_table = tables[5].df.iloc[1].str.split(n=8, expand=True)
# #     print(test_table.index)
# #     print(test_table)
#     test_table.columns = ["tot_tests", 'total_pcr_tests', 'total_serology_tests'
#                           , 'total_antigen_tests','total_positive_tests'
#                           , 'total_pcr_positive', 'total_serology_positive'
#                           , 'total_antigen_positive']
#     test_table['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")


# #     test_table.date=pd.to_datetime(test_table.date)
#     test_table=test_table.replace(",", "", regex=True)
#     test_list.append(test_table)
# df_167_169=pd.concat(test_list).reset_index(drop=True)
# df_167_169 = df_167_169[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# test_list=[]
# links=links_df.link.iloc[171:210]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,121,580,60'], split_text=True)
#     # tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,151,580,60'], split_text=True)

#     test_table=tables[0].df.iloc[3].str.replace(",", "")
#     test_dict['date']=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
#     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['total_positive_tests']=test_table[4]
#     test_dict['total_pcr_positive']=test_table[5]
#     test_dict['total_serology_positive']=test_table[6]
#     test_dict['total_antigen_positive']=test_table[7]

#     test_list.append(test_dict)
# df_210=pd.DataFrame(test_list)
# df_210 = df_210[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# test_list=[]
# links=links_df.link.iloc[210:224]
# for link in links:
#     test_dict={}
# #     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,121,580,60'], split_text=True)
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,151,580,60'], split_text=True)

#     test_table=tables[0].df.iloc[3].str.replace(",", "")
#     test_dict['date']=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
#     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['total_positive_tests']=test_table[4]
#     test_dict['total_pcr_positive']=test_table[5]
#     test_dict['total_serology_positive']=test_table[6]
#     test_dict['total_antigen_positive']=test_table[7]

#     test_list.append(test_dict)
# df_210_224=pd.DataFrame(test_list)
# df_210_224 = df_210_224[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# test_list=[]
# # for link in 
# link=links_df.link.iloc[224]

# test_dict={}
# tables=camelot.read_pdf(link, flavor='lattice', pages='1')
# test_table = tables[4].df.iloc[1].str.split(n=8, expand=True)
# #     print(test_table)
# test_table.columns = ["tot_tests", 'total_pcr_tests', 'total_serology_tests'
#                       , 'total_antigen_tests','total_positive_tests'
#                       , 'total_pcr_positive', 'total_serology_positive'
#                       , 'total_antigen_positive']
# test_table['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")

# #     test_table.date=pd.to_datetime(test_table.date)
# test_table=test_table.replace(",", "", regex=True)
# test_list.append(test_table)
# df_224=pd.concat(test_list).reset_index(drop=True)
# df_224 = df_224[['date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# merged_224=pd.concat([df_1230_0707, df_165, df_166_170, df_167_169, df_210, df_210_224, df_224])
# merged_224

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[225:265]
# for link in links:
    
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     test_table = tables[4].df.iloc[0].str.replace(",", "")
#     # test_dict['tot_test']

#     test_dict["tot_tests"]=test_table[3]
#     test_dict['total_pcr_tests']=test_table[0]
#     test_dict['total_serology_tests'] =test_table[1]
#     test_dict['total_antigen_tests']=test_table[2]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_264=pd.DataFrame(test_list)

# %% [raw]
# for links from 265 to 352 [264:352] -dates 0809 to 1105

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[265:352]
# for link in links:
    
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     test_table = tables[3].df.iloc[0].str.replace(",", "")
#     # test_dict['tot_test']

#     test_dict["tot_tests"]=test_table[3]
#     test_dict['total_pcr_tests']=test_table[0]
#     test_dict['total_serology_tests'] =test_table[1]
#     test_dict['total_antigen_tests']=test_table[2]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_352=pd.DataFrame(test_list)

# %%
# test_list=[]
# # for link in 
# link=links_df.link.iloc[352]
# # for link in links:
# test_dict={}
# tables=camelot.read_pdf(link, flavor='lattice', pages='1')
# test_table = tables[2].df[1].str.replace(",", "")

# test_dict["tot_tests"]=test_table[0]
# test_dict['total_pcr_tests']=test_table[1]
# test_dict['total_serology_tests'] =test_table[2]
# test_dict['total_antigen_tests']=test_table[3]
# test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
# test_list.append(test_dict)
# df_353=pd.DataFrame(test_list)

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[353:370]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     test_table = tables[2].df[1].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
#     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)


# df_370=pd.DataFrame(test_list)

# %% [raw]
# for links 0601 to 0723 [368:421]

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[370:379]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,421,280,310'])
#     test_table = tables[0].df[2].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
# # #     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_379=pd.DataFrame(test_list)

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[379:382]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,421,280,310'])
#     test_table = tables[0].df[2].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[2]
#     test_dict['total_pcr_tests']=test_table[3]
#     test_dict['total_serology_tests'] =test_table[4]
# # #     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_382=pd.DataFrame(test_list)

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[382:398]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,421,280,310'])
#     test_table = tables[0].df[2].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
# # #     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)
# #     print(link,test_table)

# df_398=pd.DataFrame(test_list)

# %%
# test_list=[]
# # for link in 
# links=links_df.link.iloc[398:411]
# for link in links:
#     test_dict={}
#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,401,280,310'])
#     test_table = tables[0].df[2].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
# # #     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_411=pd.DataFrame(test_list)

# %%
# links=links_df.link.iloc[411:422]
# test_list=[]
# for link in links:
#     test_dict={}

#     tables=camelot.read_pdf(link, flavor='stream',table_areas=['37,381,280,300'])
#     test_table = tables[0].df[2].str.replace(",", "")
#     test_dict["tot_tests"]=test_table[0]
#     test_dict['total_pcr_tests']=test_table[1]
#     test_dict['total_serology_tests'] =test_table[2]
# # #     test_dict['total_antigen_tests']=test_table[3]
#     test_dict['date'] = link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     test_list.append(test_dict)

# df_421=pd.DataFrame(test_list)

# %%
# merged_264_421 =pd.concat([df_264, df_352, df_353, df_370, df_379, df_382, df_398, df_411, df_421])
# merged_264_421

# %%
# merged_224

# %%
# merged_264_421

# %%
# df=pd.concat([merged_224, merged_264_421])

# %%
# df=df.reset_index(drop=True)

# %%
# df.to_csv("master_testing.csv", index=False)

# %%
# date_df=pd.DataFrame(df.date.str.split(r'(\d\d)',expand=True)[1] + "-"+df.date.str.split(r'(\d\d)',expand=True)[3])

# %%
# date_df=date_df.reset_index(drop=True)
# date_df["year_2021"]="2021"+"-"+date_df.head(208)[0]
# date_df["year_2020"]="2020"+"-"+date_df[208:][0]
# date_df['report_date']=date_df.year_2021.fillna(date_df.year_2020)
# date_df = date_df[['report_date']]
# test_df=pd.concat([df, date_df], axis=1)
# test_df = test_df[['report_date', 'tot_tests', 'total_pcr_tests', 'total_serology_tests',
#        'total_antigen_tests', 'total_positive_tests', 'total_pcr_positive',
#        'total_serology_positive', 'total_antigen_positive']]

# %%
# old_data=pd.DataFrame([{"report_date":"2020-05-31","total_pcr_tests":213586.00},
# {"report_date":"2020-05-30","total_pcr_tests":208034.00},
# {"report_date":"2020-05-29","total_pcr_tests":221118.00},
# {"report_date":"2020-05-28","total_pcr_tests":181948.00},
# {"report_date":"2020-05-27","total_pcr_tests":181948.00},
# {"report_date":"2020-05-26","total_pcr_tests":169736.00},
# {"report_date":"2020-05-25","total_pcr_tests":169736.00},
# {"report_date":"2020-05-24","total_pcr_tests":169736.00},
# {"report_date":"2020-05-23","total_pcr_tests":171338.00},
# {"report_date":"2020-05-22","total_pcr_tests":166240.00},
# {"report_date":"2020-05-21","total_pcr_tests":158672.00},
# {"report_date":"2020-05-20","total_pcr_tests":153800.00},
# {"report_date":"2020-05-19","total_pcr_tests":153800.00},
# {"report_date":"2020-05-18","total_pcr_tests":129405.00},
# {"report_date":"2020-05-17","total_pcr_tests":129405.00},
# {"report_date":"2020-05-16","total_pcr_tests":127698.00},
# {"report_date":"2020-05-15","total_pcr_tests":121246.00},
# {"report_date":"2020-05-14","total_pcr_tests":110609.00},
# {"report_date":"2020-05-13","total_pcr_tests":104001.00},
# {"report_date":"2020-05-12","total_pcr_tests":104001.00},
# {"report_date":"2020-05-11","total_pcr_tests":86900.00},
# {"report_date":"2020-05-10","total_pcr_tests":86900.00},
# {"report_date":"2020-05-09","total_pcr_tests":86428.00},
# {"report_date":"2020-05-08","total_pcr_tests":81391.00},
# {"report_date":"2020-05-07","total_pcr_tests":78603.00},
# {"report_date":"2020-05-06","total_pcr_tests":61013.00},
# {"report_date":"2020-05-05","total_pcr_tests":60046.00},
# {"report_date":"2020-05-04","total_pcr_tests":58408.00},
# {"report_date":"2020-05-03","total_pcr_tests":57648.00},
# {"report_date":"2020-05-02","total_pcr_tests":57648.00},
# {"report_date":"2020-05-01","total_pcr_tests":56611.00},
# {"report_date":"2020-04-30","total_pcr_tests":54101.00},
# {"report_date":"2020-04-29","total_pcr_tests":52410.00},
# {"report_date":"2020-04-28","total_pcr_tests":48798.00},
# {"report_date":"2020-04-27","total_pcr_tests":48474.00},
# {"report_date":"2020-04-26","total_pcr_tests":46558.00},
# {"report_date":"2020-04-25","total_pcr_tests":44962.00},
# {"report_date":"2020-04-24","total_pcr_tests":42844.00},
# {"report_date":"2020-04-23","total_pcr_tests":36075.00},
# {"report_date":"2020-04-22","total_pcr_tests":33328.00},
# {"report_date":"2020-04-21","total_pcr_tests":32820.00},
# {"report_date":"2020-04-20","total_pcr_tests":32572.00},
# {"report_date":"2020-04-19","total_pcr_tests":32225.00},
# {"report_date":"2020-04-18","total_pcr_tests":30596.00},
# {"report_date":"2020-04-17","total_pcr_tests":29747.00},
# {"report_date":"2020-04-16","total_pcr_tests":28324.00},
# {"report_date":"2020-04-15","total_pcr_tests":27697.00},
# {"report_date":"2020-04-14","total_pcr_tests":26683.00},
# {"report_date":"2020-04-13","total_pcr_tests":25866.00},
# {"report_date":"2020-04-12","total_pcr_tests":24567.00},
# {"report_date":"2020-04-11","total_pcr_tests":24288.00},
# {"report_date":"2020-04-10","total_pcr_tests":24288.00},
# {"report_date":"2020-04-09","total_pcr_tests":21801.00},
# {"report_date":"2020-04-08","total_pcr_tests":21604.00},
# {"report_date":"2020-04-07","total_pcr_tests":19955.00},
# {"report_date":"2020-04-06","total_pcr_tests":18767.00},
# {"report_date":"2020-04-05","total_pcr_tests":16663.00},
# {"report_date":"2020-04-04","total_pcr_tests":15572.00},
# {"report_date":"2020-04-03","total_pcr_tests":12804.00},
# {"report_date":"2020-04-02","total_pcr_tests":7900.00},
# {"report_date":"2020-04-01","total_pcr_tests":7556.00},
# {"report_date":"2020-03-31","total_pcr_tests":6810.00},
# {"report_date":"2020-03-30","total_pcr_tests":6018.00},
# {"report_date":"2020-03-29","total_pcr_tests":5541.00},
# {"report_date":"2020-03-28","total_pcr_tests":5123.00},
# {"report_date":"2020-03-27","total_pcr_tests":4016.00},
# {"report_date":"2020-03-26","total_pcr_tests":3300.00},
# {"report_date":"2020-03-25","total_pcr_tests":3022.00},
# {"report_date":"2020-03-24","total_pcr_tests":1886.00},
# {"report_date":"2020-03-23","total_pcr_tests":1866.00},
# {"report_date":"2020-03-22","total_pcr_tests":1571.00},
# {"report_date":"2020-03-21","total_pcr_tests":768.00},
# {"report_date":"2020-03-20","total_pcr_tests":639.00},
# {"report_date":"2020-03-19","total_pcr_tests":489.00},
# {"report_date":"2020-03-18","total_pcr_tests":380.00},
# {"report_date":"2020-03-17","total_pcr_tests":317.00},
# {"report_date":"2020-03-16","total_pcr_tests":255.00},
# {"report_date":"2020-03-15","total_pcr_tests":155.00},
# {"report_date":"2020-03-14","total_pcr_tests":153.00},
# {"report_date":"2020-03-13","total_pcr_tests":118.00},
# {"report_date":"2020-03-12","total_pcr_tests":64.00},
# {"report_date":"2020-03-11","total_pcr_tests":54.00},
# {"report_date":"2020-03-10","total_pcr_tests":34.00},
# {"report_date":"2020-03-09","total_pcr_tests":21.00},
# {"report_date":"2020-03-08","total_pcr_tests":14.00},
# {"report_date":"2020-03-07","total_pcr_tests":10.00},
# {"report_date":"2020-03-06","total_pcr_tests":7.00}])

# %%
# master_test=pd.concat([test_df,old_data]).reset_index(drop=True)
# master_test=master_test.rename(columns={'report_date': 'date'})

# %%
# master_test.to_csv("master_testing.csv", index=False)

# %%
# master_test

# %% [markdown]
# # Hospitalizations

# %%
# hosp_list=[]
# links = links_df.link[:228]
# for link in links:
#     hosp_dict={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='2')
#     hosp_table=tables[2].df
#     hosp_dict["date"]=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     hosp_dict["hospitalized"]=hosp_table.iloc[1][1]
#     hosp_dict["in_icu"]=hosp_table.iloc[2][1]
#     hosp_dict["on_vent"]=hosp_table.iloc[3][1]

#     hosp_list.append(hosp_dict)
# df_1215=pd.DataFrame(hosp_list)
# df_1215=df_1215.replace(",","", regex=True)
# df_1215.date=df_1215.date + "-22222"
# df_1215.date=df_1215.date.str.replace("21-22222", "21").str.replace("2021-22222","21").str.replace(
# "-22222", "20")
# df_1215.date=df_1215.date.str.replace("1221", "122120").str.replace("10421", "010421")

# # df_1215.to_csv("data_1215.csv", index=False)
# #clean it up
# df_1215=pd.read_csv("data_1215.csv")
# df_1215.date=pd.to_datetime(df_1215.date, format='%m%d%y')
# # df_1215.to_csv("data_1215.csv", index=False)

# %%
# hosp_list=[]
# links = links_df.link[228:262]
# for link in links:
#     hosp_dict={}
#     tables=camelot.read_pdf(link, flavor='lattice', pages='1')
#     hosp_table=tables[3].df
#     hosp_dict["date"]=link.split("Report")[1].replace(".pdf", "").replace("-COVID19","")
#     hosp_dict["hospitalized"]=hosp_table[hosp_table[0].str.contains("Hospitalized")
#           ].reset_index(drop=True).iloc[0][1]
#     hosp_dict["in_icu"]=hosp_table[hosp_table[0].str.contains("ICU")
#           ].reset_index(drop=True).iloc[0][1]
#     hosp_dict["on_vent"]=hosp_table[hosp_table[0].str.contains("On Ventilators")
#           ].reset_index(drop=True).iloc[0][1]
    
#     hosp_list.append(hosp_dict)
# df_1110_1214=pd.DataFrame(hosp_list)
# df_1110_1214=df_1110_1214.replace(",","", regex=True)

# df_1110_1214.date=df_1110_1214.date+"20"
# df_1110_1214.date=pd.to_datetime(df_1110_1214.date, format='%m%d%y')

# df_1110_1214=df_1110_1214.reset_index(drop=True)

# %%
# {"date":"2020-05-18","hospitalized":381.00,"in_icu":218.00},
# {"date":"2020-05-17","hospitalized":381.00,"in_icu":218.00},
# {"date":"2020-05-16","hospitalized":381.00,"in_icu":218.00},
# {"date":"2020-05-15","hospitalized":385.00,"in_icu":220.00},
# {"date":"2020-05-14","hospitalized":377.00,"in_icu":215.00},
# {"date":"2020-05-13","hospitalized":379.00,"in_icu":215.00},
# {"date":"2020-05-12","hospitalized":383.00,"in_icu":220.00},
# {"date":"2020-05-11","hospitalized":394.00,"in_icu":226.00},
# {"date":"2020-05-10","hospitalized":394.00,"in_icu":226.00},
# {"date":"2020-05-09","hospitalized":369.00,"in_icu":210.00},
# {"date":"2020-05-08","hospitalized":356.00,"in_icu":199.00},
# {"date":"2020-05-07","hospitalized":351.00,"in_icu":190.00},
# {"date":"2020-05-06","hospitalized":347.00,"in_icu":189.00},
# {"date":"2020-05-05","hospitalized":333.00,"in_icu":174.00},
# {"date":"2020-05-04","hospitalized":329.00,"in_icu":170.00},
# {"date":"2020-05-03","hospitalized":334.00,"in_icu":178.00},
# {"date":"2020-05-02","hospitalized":334.00,"in_icu":178.00},
# {"date":"2020-05-01","hospitalized":330.00,"in_icu":178.00},
# {"date":"2020-04-30","hospitalized":325.00,"in_icu":176.00},
# {"date":"2020-04-29","hospitalized":320.00,"in_icu":170.00},
# {"date":"2020-04-28","hospitalized":313.00,"in_icu":165.00},
# {"date":"2020-04-27","hospitalized":308.00,"in_icu":166.00},
# {"date":"2020-04-26","hospitalized":301.00,"in_icu":164.00},
# {"date":"2020-04-25","hospitalized":303.00,"in_icu":164.00},
# {"date":"2020-04-24","hospitalized":302.00,"in_icu":163.00},
# {"date":"2020-04-23","hospitalized":301.00,"in_icu":161.00},
# {"date":"2020-04-22","hospitalized":286.00,"in_icu":165.00},
# {"date":"2020-04-21","hospitalized":263.00,"in_icu":147.00},
# {"date":"2020-04-20","hospitalized":274.00,"in_icu":155.00},
# {"date":"2020-04-19","hospitalized":274.00,"in_icu":155.00},
# {"date":"2020-04-18","hospitalized":360.00,"in_icu":227.00},
# {"date":"2020-04-17","hospitalized":477.00,"in_icu":333.00},
# {"date":"2020-04-16","hospitalized":412.00,"in_icu":252.00},
# {"date":"2020-04-15","hospitalized":305.00,"in_icu":137.00},
# {"date":"2020-04-14","hospitalized":299.00,"in_icu":136.00},
# {"date":"2020-04-13","hospitalized":289.00,"in_icu":136.00},
# {"date":"2020-04-12","hospitalized":271.00,"in_icu":105.00},
# {"date":"2020-04-11","hospitalized":271.00,"in_icu":105.00},
# {"date":"2020-04-10","hospitalized":271.00,"in_icu":105.00}])

# df_0410_1110.date=pd.to_datetime(df_0410_1110.date, format='%Y-%m-%d')
# df_0410_1110=df_0410_1110.sort_values("date", ascending=False).reset_index(drop=True)
# hosp_df=pd.concat([df_1215,df_1110_1214,df_0410_1110]).reset_index(drop=True)
# hosp_df.to_csv("hospitalization_data.csv", index=False)
