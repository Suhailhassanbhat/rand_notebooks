# %% [raw]
# {
#   "STUSAB": "state_abbr",
#   "SUMLEV": "summary_level",
#   "GEOVAR": "Geographic Variant",
#   "GEOCOMP": "Geographic Component",
#   "CHARITER": "Characteristic Iteration",
#   "CIFSN": "Characteristic Iteration File Sequence Number",
#   "LOGRECNO": "Logical Record Number",
#   "GEOID": "Geographic Record Identifier",
#   "GEOCODE": "Geographic Code Identifier",
#   "REGION": "Region",
#   "DIVISION": "Division",
#   "STATE": "State (FIPS)",
#   "STATENS": "State (NS)",
#   "COUNTY": "County (FIPS)",
#   "COUNTYCC": "FIPS County Class Code",
#   "COUNTYNS": "County (NS)",
#   "COUSUB": "County Subdivision (FIPS)",
#   "COUSUBCC": "FIPS County Subdivision Class Code",
#   "COUSUBNS": "County Subdivision (NS)",
#   "SUBMCD": "Subminor Civil Division (FIPS)",
#   "SUBMCDCC": "FIPS Subminor Civil Division Class Code",
#   "SUBMCDNS": "Subminor Civil Division (NS)",
#   "ESTATE": "Estate (FIPS)",
#   "ESTATECC": "FIPS Estate Class Code",
#   "ESTATENS": "Estate (NS)",
#   "CONCIT": "Consolidated City (FIPS)",
#   "CONCITCC": "FIPS Consolidated City Class Code",
#   "CONCITNS": "Consolidated City (NS)",
#   "PLACE": "Place (FIPS)",
#   "PLACECC": "FIPS Place Class Code",
#   "PLACENS": "Place (NS)",
#   "TRACT": "Census Tract",
#   "BLKGRP": "Block Group",
#   "BLOCK": "Block",
#   "AIANHH": "American Indian Area/Alaska Native Area/Hawaiian Home Land (Census)",
#   "AIHHTLI": "American Indian Trust Land/Hawaiian Home Land Indicator",
#   "AIANHHFP": "American Indian Area/Alaska Native Area/Hawaiian Home Land (FIPS)",
#   "AIANHHCC": "FIPS American Indian Area/Alaska Native Area/Hawaiian Home Land Class Code",
#   "AIANHHNS": "American Indian Area/Alaska Native Area/Hawaiian Home Land (NS)",
#   "AITS": "American Indian Tribal Subdivision (Census)",
#   "AITSFP": "American Indian Tribal Subdivision (FIPS)",
#   "AITSCC": "FIPS American Indian Tribal Subdivision Class Code",
#   "AITSNS": "American Indian Tribal Subdivision (NS)",
#   "TTRACT": "Tribal Census Tract",
#   "TBLKGRP": "Tribal Block Group",
#   "ANRC": "Alaska Native Regional Corporation (FIPS)",
#   "ANRCCC": "FIPS Alaska Native Regional Corporation Class Code",
#   "ANRCNS": "Alaska Native Regional Corporation (NS)",
#   "CBSA": "Metropolitan Statistical Area/Micropolitan Statistical Area",
#   "MEMI": "Metropolitan/Micropolitan Indicator",
#   "CSA": "Combined Statistical Area",
#   "METDIV": "Metropolitan Division",
#   "NECTA": "New England City and Town Area",
#   "NMEMI": "NECTA Metropolitan/Micropolitan Indicator",
#   "CNECTA": "Combined New England City and Town Area",
#   "NECTADIV": "New England City and Town Area Division",
#   "CBSAPCI": "Metropolitan Statistical Area/Micropolitan Statistical Area Principal City Indicator",
#   "NECTAPCI": "New England City and Town Area Principal City Indicator",
#   "UA": "Urban Area",
#   "UATYPE": "Urban Area Type",
#   "UR": "Urban/Rural",
#   "CD116": "Congressional District (116th)",
#   "CD118": "Congressional District (118th)",
#   "CD119": "Congressional District (119th)",
#   "CD120": "Congressional District (120th)",
#   "CD121": "Congressional District (121st)",
#   "SLDU18": "State Legislative District (Upper Chamber) (2018)",
#   "SLDU22": "State Legislative District (Upper Chamber) (2022)",
#   "SLDU24": "State Legislative District (Upper Chamber) (2024)",
#   "SLDU26": "State Legislative District (Upper Chamber) (2026)",
#   "SLDU28": "State Legislative District (Upper Chamber) (2028)",
#   "SLDL18": "State Legislative District (Lower Chamber) (2018)",
#   "SLDL22": "State Legislative District (Lower Chamber) (2022)",
#   "SLDL24": "State Legislative District (Lower Chamber) (2024)",
#   "SLDL26": "State Legislative District (Lower Chamber) (2026)",
#   "SLDL28": "State Legislative District (Lower Chamber) (2028)",
#   "VTD": "Voting District",
#   "VTDI": "Voting District Indicator",
#   "ZCTA": "ZIP Code Tabulation Area (5-Digit)",
#   "SDELM": "School District (Elementary)",
#   "SDSEC": "School District (Secondary)",
#   "SDUNI": "School District (Unified)",
#   "PUMA": "Public Use Microdata Area",
#   "AREALAND": "Area (Land)",
#   "AREAWATR": "Area (Water)",
#   "BASENAME": "Area Base Name",
#   "NAME": "Area Name-Legal/Statistical Area Description (LSAD) Term-Part Indicator",
#   "FUNCSTAT": "Functional Status Code",
#   "GCUNI": "Geographic Change User Note Indicator",
#   "POP100": "Population Count (100%)",
#   "HU100": "Housing Unit Count (100%)",
#   "INTPTLAT": "Internal Point (Latitude)",
#   "INTPTLON": "Internal Point (Longitude)",
#   "LSADC": "Legal/Statistical Area Description Code",
#   "PARTFLAG": "Part Flag",
#   "UGA": "Urban Growth Area"
# }

# %%
{
  "STUSAB": "State/US-Abbreviation (USPS)",
  "CHARITER": "Characteristic Iteration",
  "CIFSN": "Characteristic Iteration File Sequence Number",
  "LOGRECNO": "Logical Record Number",
  "P0010001": "Total:",
  "P0010002": "Population of one race:",
  "P0010003": "White alone",
  "P0010004": "Black or African American alone",
  "P0010005": "American Indian and Alaska Native alone",
  "P0010006": "Asian alone",
  "P0010007": "Native Hawaiian and Other Pacific Islander alone",
  "P0010008": "Some Other Race alone",
  "P0010009": "Population of two or more races:",
  "P0010010": "Population of two races:",
  "P0010011": "White; Black or African American",
  "P0010012": "White; American Indian and Alaska Native",
  "P0010013": "White; Asian",
  "P0010014": "White; Native Hawaiian and Other Pacific Islander",
  "P0010015": "White; Some Other Race",
  "P0010016": "Black or African American; American Indian and Alaska Native",
  "P0010017": "Black or African American; Asian",
  "P0010018": "Black or African American; Native Hawaiian and Other Pacific Islander",
  "P0010019": "Black or African American; Some Other Race",
  "P0010020": "American Indian and Alaska Native; Asian",
  "P0010021": "American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0010022": "American Indian and Alaska Native; Some Other Race",
  "P0010023": "Asian; Native Hawaiian and Other Pacific Islander",
  "P0010024": "Asian; Some Other Race",
  "P0010025": "Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010026": "Population of three races:",
  "P0010027": "White; Black or African American; American Indian and Alaska Native",
  "P0010028": "White; Black or African American; Asian",
  "P0010029": "White; Black or African American; Native Hawaiian and Other Pacific Islander",
  "P0010030": "White; Black or African American; Some Other Race",
  "P0010031": "White; American Indian and Alaska Native; Asian",
  "P0010032": "White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0010033": "White; American Indian and Alaska Native; Some Other Race",
  "P0010034": "White; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010035": "White; Asian; Some Other Race",
  "P0010036": "White; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010037": "Black or African American; American Indian and Alaska Native; Asian",
  "P0010038": "Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0010039": "Black or African American; American Indian and Alaska Native; Some Other Race",
  "P0010040": "Black or African American; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010041": "Black or African American; Asian; Some Other Race",
  "P0010042": "Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010043": "American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010044": "American Indian and Alaska Native; Asian; Some Other Race",
  "P0010045": "American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010046": "Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010047": "Population of four races:",
  "P0010048": "White; Black or African American; American Indian and Alaska Native; Asian",
  "P0010049": "White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0010050": "White; Black or African American; American Indian and Alaska Native; Some Other Race",
  "P0010051": "White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010052": "White; Black or African American; Asian; Some Other Race",
  "P0010053": "White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010054": "White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010055": "White; American Indian and Alaska Native; Asian; Some Other Race",
  "P0010056": "White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010057": "White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010058": "Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010059": "Black or African American; American Indian and Alaska Native; Asian; Some Other Race",
  "P0010060": "Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010061": "Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010062": "American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010063": "Population of five races:",
  "P0010064": "White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0010065": "White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race",
  "P0010066": "White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010067": "White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010068": "White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010069": "Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0010070": "Population of six races:",
  "P0010071": "White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020001": "Total:",
  "P0020002": "Hispanic or Latino",
  "P0020003": "Not Hispanic or Latino:",
  "P0020004": "Population of one race:",
  "P0020005": "White alone",
  "P0020006": "Black or African American alone",
  "P0020007": "American Indian and Alaska Native alone",
  "P0020008": "Asian alone",
  "P0020009": "Native Hawaiian and Other Pacific Islander alone",
  "P0020010": "Some Other Race alone",
  "P0020011": "Population of two or more races:",
  "P0020012": "Population of two races:",
  "P0020013": "White; Black or African American",
  "P0020014": "White; American Indian and Alaska Native",
  "P0020015": "White; Asian",
  "P0020016": "White; Native Hawaiian and Other Pacific Islander",
  "P0020017": "White; Some Other Race",
  "P0020018": "Black or African American; American Indian and Alaska Native",
  "P0020019": "Black or African American; Asian",
  "P0020020": "Black or African American; Native Hawaiian and Other Pacific Islander",
  "P0020021": "Black or African American; Some Other Race",
  "P0020022": "American Indian and Alaska Native; Asian",
  "P0020023": "American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0020024": "American Indian and Alaska Native; Some Other Race",
  "P0020025": "Asian; Native Hawaiian and Other Pacific Islander",
  "P0020026": "Asian; Some Other Race",
  "P0020027": "Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020028": "Population of three races:",
  "P0020029": "White; Black or African American; American Indian and Alaska Native",
  "P0020030": "White; Black or African American; Asian",
  "P0020031": "White; Black or African American; Native Hawaiian and Other Pacific Islander",
  "P0020032": "White; Black or African American; Some Other Race",
  "P0020033": "White; American Indian and Alaska Native; Asian",
  "P0020034": "White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0020035": "White; American Indian and Alaska Native; Some Other Race",
  "P0020036": "White; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020037": "White; Asian; Some Other Race",
  "P0020038": "White; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020039": "Black or African American; American Indian and Alaska Native; Asian",
  "P0020040": "Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0020041": "Black or African American; American Indian and Alaska Native; Some Other Race",
  "P0020042": "Black or African American; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020043": "Black or African American; Asian; Some Other Race",
  "P0020044": "Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020045": "American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020046": "American Indian and Alaska Native; Asian; Some Other Race",
  "P0020047": "American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020048": "Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020049": "Population of four races:",
  "P0020050": "White; Black or African American; American Indian and Alaska Native; Asian",
  "P0020051": "White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander",
  "P0020052": "White; Black or African American; American Indian and Alaska Native; Some Other Race",
  "P0020053": "White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020054": "White; Black or African American; Asian; Some Other Race",
  "P0020055": "White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020056": "White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020057": "White; American Indian and Alaska Native; Asian; Some Other Race",
  "P0020058": "White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020059": "White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020060": "Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020061": "Black or African American; American Indian and Alaska Native; Asian; Some Other Race",
  "P0020062": "Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020063": "Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020064": "American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020065": "Population of five races:",
  "P0020066": "White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander",
  "P0020067": "White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race",
  "P0020068": "White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020069": "White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020070": "White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020071": "Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race",
  "P0020072": "Population of six races:",
  "P0020073": "White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race"
}
# Out:
# {'STUSAB': 'State/US-Abbreviation (USPS)',
#  'CHARITER': 'Characteristic Iteration',
#  'CIFSN': 'Characteristic Iteration File Sequence Number',
#  'LOGRECNO': 'Logical Record Number',
#  'P0010001': 'Total:',
#  'P0010002': 'Population of one race:',
#  'P0010003': 'White alone',
#  'P0010004': 'Black or African American alone',
#  'P0010005': 'American Indian and Alaska Native alone',
#  'P0010006': 'Asian alone',
#  'P0010007': 'Native Hawaiian and Other Pacific Islander alone',
#  'P0010008': 'Some Other Race alone',
#  'P0010009': 'Population of two or more races:',
#  'P0010010': 'Population of two races:',
#  'P0010011': 'White; Black or African American',
#  'P0010012': 'White; American Indian and Alaska Native',
#  'P0010013': 'White; Asian',
#  'P0010014': 'White; Native Hawaiian and Other Pacific Islander',
#  'P0010015': 'White; Some Other Race',
#  'P0010016': 'Black or African American; American Indian and Alaska Native',
#  'P0010017': 'Black or African American; Asian',
#  'P0010018': 'Black or African American; Native Hawaiian and Other Pacific Islander',
#  'P0010019': 'Black or African American; Some Other Race',
#  'P0010020': 'American Indian and Alaska Native; Asian',
#  'P0010021': 'American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0010022': 'American Indian and Alaska Native; Some Other Race',
#  'P0010023': 'Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010024': 'Asian; Some Other Race',
#  'P0010025': 'Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010026': 'Population of three races:',
#  'P0010027': 'White; Black or African American; American Indian and Alaska Native',
#  'P0010028': 'White; Black or African American; Asian',
#  'P0010029': 'White; Black or African American; Native Hawaiian and Other Pacific Islander',
#  'P0010030': 'White; Black or African American; Some Other Race',
#  'P0010031': 'White; American Indian and Alaska Native; Asian',
#  'P0010032': 'White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0010033': 'White; American Indian and Alaska Native; Some Other Race',
#  'P0010034': 'White; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010035': 'White; Asian; Some Other Race',
#  'P0010036': 'White; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010037': 'Black or African American; American Indian and Alaska Native; Asian',
#  'P0010038': 'Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0010039': 'Black or African American; American Indian and Alaska Native; Some Other Race',
#  'P0010040': 'Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010041': 'Black or African American; Asian; Some Other Race',
#  'P0010042': 'Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010043': 'American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010044': 'American Indian and Alaska Native; Asian; Some Other Race',
#  'P0010045': 'American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010046': 'Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010047': 'Population of four races:',
#  'P0010048': 'White; Black or African American; American Indian and Alaska Native; Asian',
#  'P0010049': 'White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0010050': 'White; Black or African American; American Indian and Alaska Native; Some Other Race',
#  'P0010051': 'White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010052': 'White; Black or African American; Asian; Some Other Race',
#  'P0010053': 'White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010054': 'White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010055': 'White; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0010056': 'White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010057': 'White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010058': 'Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010059': 'Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0010060': 'Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010061': 'Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010062': 'American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010063': 'Population of five races:',
#  'P0010064': 'White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0010065': 'White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0010066': 'White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010067': 'White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010068': 'White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010069': 'Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0010070': 'Population of six races:',
#  'P0010071': 'White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020001': 'Total:',
#  'P0020002': 'Hispanic or Latino',
#  'P0020003': 'Not Hispanic or Latino:',
#  'P0020004': 'Population of one race:',
#  'P0020005': 'White alone',
#  'P0020006': 'Black or African American alone',
#  'P0020007': 'American Indian and Alaska Native alone',
#  'P0020008': 'Asian alone',
#  'P0020009': 'Native Hawaiian and Other Pacific Islander alone',
#  'P0020010': 'Some Other Race alone',
#  'P0020011': 'Population of two or more races:',
#  'P0020012': 'Population of two races:',
#  'P0020013': 'White; Black or African American',
#  'P0020014': 'White; American Indian and Alaska Native',
#  'P0020015': 'White; Asian',
#  'P0020016': 'White; Native Hawaiian and Other Pacific Islander',
#  'P0020017': 'White; Some Other Race',
#  'P0020018': 'Black or African American; American Indian and Alaska Native',
#  'P0020019': 'Black or African American; Asian',
#  'P0020020': 'Black or African American; Native Hawaiian and Other Pacific Islander',
#  'P0020021': 'Black or African American; Some Other Race',
#  'P0020022': 'American Indian and Alaska Native; Asian',
#  'P0020023': 'American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0020024': 'American Indian and Alaska Native; Some Other Race',
#  'P0020025': 'Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020026': 'Asian; Some Other Race',
#  'P0020027': 'Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020028': 'Population of three races:',
#  'P0020029': 'White; Black or African American; American Indian and Alaska Native',
#  'P0020030': 'White; Black or African American; Asian',
#  'P0020031': 'White; Black or African American; Native Hawaiian and Other Pacific Islander',
#  'P0020032': 'White; Black or African American; Some Other Race',
#  'P0020033': 'White; American Indian and Alaska Native; Asian',
#  'P0020034': 'White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0020035': 'White; American Indian and Alaska Native; Some Other Race',
#  'P0020036': 'White; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020037': 'White; Asian; Some Other Race',
#  'P0020038': 'White; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020039': 'Black or African American; American Indian and Alaska Native; Asian',
#  'P0020040': 'Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0020041': 'Black or African American; American Indian and Alaska Native; Some Other Race',
#  'P0020042': 'Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020043': 'Black or African American; Asian; Some Other Race',
#  'P0020044': 'Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020045': 'American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020046': 'American Indian and Alaska Native; Asian; Some Other Race',
#  'P0020047': 'American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020048': 'Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020049': 'Population of four races:',
#  'P0020050': 'White; Black or African American; American Indian and Alaska Native; Asian',
#  'P0020051': 'White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'P0020052': 'White; Black or African American; American Indian and Alaska Native; Some Other Race',
#  'P0020053': 'White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020054': 'White; Black or African American; Asian; Some Other Race',
#  'P0020055': 'White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020056': 'White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020057': 'White; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0020058': 'White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020059': 'White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020060': 'Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020061': 'Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0020062': 'Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020063': 'Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020064': 'American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020065': 'Population of five races:',
#  'P0020066': 'White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'P0020067': 'White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'P0020068': 'White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020069': 'White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020070': 'White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020071': 'Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'P0020072': 'Population of six races:',
#  'P0020073': 'White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race'}

# %%
import pandas as pd
import re

# %%
# df=pd.read_csv("2020 PL Geoheader.csv", dtype={"SUMLEV":str})
# df1=pd.read_csv("2020 PL Segment 1.csv")
# df1=df1[["LOGRECNO", "P0020001", "P0020002",
#                                     "P0020003",
#                                     "P0020004",
#                                     "P0020005",
#                                     "P0020006",
#                                     "P0020007",
#                                     "P0020008",
#                                     "P0020009",
#                                     "P0020010"]]
# df1=df1.rename(columns={
#     "P0020001":"total_pop", 
#     "P0020002":"hisp_latino",
#     "P0020003":"not_hisp_latino",
#     "P0020004":"one_race",
#     "P0020005":"white_alone",
#     "P0020006":"black_alone",
#     "P0020007":"aian_alone",
#     "P0020008":"asian_alone",
#     "P0020009":'naopi_alone',
#     "P0020010":"other_race"})
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3,9,18,27,30,57,58,77,78,86,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
seg1_columns=df1.columns

# %%
seg1_columns
# Out:
# Index(['FILEID', 'STUSAB', 'CHARITER', 'CIFSN', 'LOGRECNO', 'P0010001',
#        'P0010002', 'P0010003', 'P0010004', 'P0010005',
#        ...
#        'P0020064', 'P0020065', 'P0020066', 'P0020067', 'P0020068', 'P0020069',
#        'P0020070', 'P0020071', 'P0020072', 'P0020073'],
#       dtype='object', length=149)

# %% [markdown]
# # combine files here

# %%
# data=pd.read_csv("tab2010_tab2020_st21_ky.txt", sep="|", dtype={"COUNTY_2010":str, 'COUNTY_2020':str, "STATE_2010":str
#                                                                ,"TRACT_2010":str, "STATE_2020":str
#                                                                ,"TRACT_2020":str, })
# data.columns

# data['TRACT_CODE_2010'] = data.STATE_2010 + data.COUNTY_2010 + data.TRACT_2010  
# data['TRACT_CODE_2020'] = data.STATE_2020 + data.COUNTY_2020 + data.TRACT_2020

# %%
# header=pd.read_csv("2020 PL Header.csv")

# geo_df=pd.read_csv("kygeo2020.pl.csv", sep="|", header=None)
# seg1_df=pd.read_csv("ky000012020.pl.csv", sep="|", header=None)
# seg1_df.columns =seg1_columns

# %%
# seg1_df.to_csv("seg1_file.csv", index=False)

# %%
# geo_df.to_csv("geo_file.csv", index=False)

# %% [markdown]
# # Read new files

# %%
geoData=pd.read_csv("geo_file.csv")
raceData=pd.read_csv("seg1_file.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3,9,18,27,30,57,58,77,78,86,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
geoData.shape
# Out:
# (221057, 97)

# %%
raceData.shape
# Out:
# (221057, 149)

# %%
filteredGeo=geoData[['SUMLEV', 'LOGRECNO', 'GEOID', 'GEOCODE','NAME','INTPTLAT', 'INTPTLON']]

# %%
filteredRace=raceData[["LOGRECNO", "P0020001", 'P0010002',"P0020002",
                                    "P0020003",
                                    "P0020004",
                                    "P0020005",
                                    "P0020006",
                                    "P0020007",
                                    "P0020008",
                                    "P0020009",
                                    "P0020010"]]

filteredRace=filteredRace.rename(columns={
    "P0020001":"total_pop", 
    'P0010002':"one_race_pop",
    "P0020002":"hisp_latino",
    "P0020003":"not_hisp_latino",
    "P0020004":"one_race_nh",
    "P0020005":"white_alone_nh",
    "P0020006":"black_alone_nh",
    "P0020007":"aian_alone_nh",
    "P0020008":"asian_alone_nh",
    "P0020009":'naopi_alone_nh',
    "P0020010":"other_race_nh"})

# %%
race_final=pd.merge(filteredGeo, filteredRace)

# %% [markdown]
# ### Census Tracts Analysis

# %%
# filter for census tracts

tractsData=race_final[race_final.SUMLEV == 140].reset_index(drop=True)

# %%
tractsData["multi_race"]=tractsData.total_pop-tractsData.hisp_latino-tractsData.one_race_nh

# %%
tractsData=tractsData[['GEOCODE', 'NAME','total_pop', 'one_race_pop', 'multi_race','hisp_latino',
       'not_hisp_latino', 'one_race_nh', 'white_alone_nh', 'black_alone_nh',
       'aian_alone_nh', 'asian_alone_nh', 'naopi_alone_nh', 'other_race_nh',
        'INTPTLAT', 'INTPTLON']]

# %%
# tractsData.to_csv("tracts_div_ky2020.csv", index=False)

# %%
import pandas as pd

# %%
df=pd.read_csv("ky_cleaned_files/tracts_div_ky2020.csv")

# %%
tractsData
# Out:
#           GEOCODE                  NAME  total_pop  one_race_pop  multi_race  \
# 0     21001970100     Census Tract 9701       1621          1559          51
# 1     21001970200     Census Tract 9702       1755          1701          43
# 2     21001970300     Census Tract 9703       3005          2916          63
# 3     21001970401  Census Tract 9704.01       4346          4194         126
# 4     21001970402  Census Tract 9704.02       4535          4378         132
# ...           ...                   ...        ...           ...         ...
# 1301  21239050106   Census Tract 501.06       3921          3754         108
# 1302  21239050107   Census Tract 501.07       4167          3949         135
# 1303  21239050200      Census Tract 502       3759          3557         157
# 1304  21239050300      Census Tract 503       1773          1707          47
# 1305  21239050400      Census Tract 504       2295          2207          47
#
#       hisp_latino  not_hisp_latino  one_race_nh  white_alone_nh  \
# 0              36             1585         1534            1525
# 1              54             1701         1658            1616
# 2             103             2902         2839            2818
# 3             171             4175         4049            3835
# 4             199             4336         4204            3894
# ...           ...              ...          ...             ...
# 1301          197             3724         3616            3493
# 1302          300             3867         3732            3508
# 1303          119             3640         3483            3434
# 1304          121             1652         1605            1551
# 1305          129             2166         2119            1979
#
#       black_alone_nh  aian_alone_nh  asian_alone_nh  naopi_alone_nh  \
# 0                  6              1               0               0
# 1                 35              6               0               0
# 2                  9              3               9               0
# 3                196              2               9               3
# 4                226              6              37               2
# ...              ...            ...             ...             ...
# 1301              94              0              15               0
# 1302             174              2              39               0
# 1303              22              4              13               3
# 1304              32              5               6               3
# 1305             120              6               7               1
#
#       other_race_nh   INTPTLAT   INTPTLON
# 0                 2  37.235091 -85.158997
# 1                 1  37.172349 -85.337815
# 2                 0  37.128164 -85.156588
# 3                 4  37.052371 -85.328457
# 4                39  37.122300 -85.276557
# ...             ...        ...        ...
# 1301             14  38.021165 -84.687406
# 1302              9  38.044747 -84.687097
# 1303              7  37.960814 -84.732228
# 1304              8  38.098915 -84.773211
# 1305              6  38.151934 -84.707427
#
# [1306 rows x 16 columns]

# %%
df.head(1)
# Out:
#        GEOCODE               NAME  total_pop  one_race_pop  multi_race  \
# 0  21001970100  Census Tract 9701       1621          1559          51
#
#    hisp_latino  not_hisp_latino  one_race_nh  white_alone_nh  black_alone_nh  \
# 0           36             1585         1534            1525               6
#
#    aian_alone_nh  asian_alone_nh  naopi_alone_nh  other_race_nh   INTPTLAT  \
# 0              1               0               0              2  37.235091
#
#     INTPTLON
# 0 -85.158997

# %%
# df['pct_one_race'] = 


df['other_races']=df.aian_alone_nh + df.naopi_alone_nh + df.other_race_nh

df["pct_hisp_lat"]=(df.hisp_latino*100/df.total_pop).round(2)
df["pct_multi_race"]=(df.multi_race*100/df.total_pop).round(2)
df["pct_white"]=(df.white_alone_nh*100/df.total_pop).round(2)
df["pct_black"]=(df.black_alone_nh*100/df.total_pop).round(2)
df["pct_asian"]=(df.asian_alone_nh*100/df.total_pop).round(2)
df["pct_other_races"]=(df.other_races*100/df.total_pop).round(2)

# %%
df=df[['GEOCODE', 'NAME', 'total_pop', 'one_race_pop', 'multi_race',
       'hisp_latino', 'not_hisp_latino', 'one_race_nh', 'white_alone_nh',
       'black_alone_nh', 'asian_alone_nh','other_races', 'pct_hisp_lat',
       'pct_multi_race', 'pct_white', 'pct_black', 'pct_asian',
       'pct_other_races']]
# .to_csv("pop_by_CT2020.csv", index=False)

# %% [markdown]
# # statewide numbers

# %%
import pandas as pd
df=pd.read_csv("2020 PL Geoheader.csv", dtype={"SUMLEV":str})
df1=pd.read_csv("2020 PL Segment 1.csv")
df1=df1[["LOGRECNO", "P0020001", 'P0010002',"P0020002",
                                    "P0020003",
                                    "P0020004",
                                    "P0020005",
                                    "P0020006",
                                    "P0020007",
                                    "P0020008",
                                    "P0020009",
                                    "P0020010"]]

df1=df1.rename(columns={
    "P0020001":"total_pop", 
    'P0010002':"one_race_pop",
    "P0020002":"hisp_latino",
    "P0020003":"not_hisp_latino",
    "P0020004":"one_race_nh",
    "P0020005":"white_alone_nh",
    "P0020006":"black_alone_nh",
    "P0020007":"aian_alone_nh",
    "P0020008":"asian_alone_nh",
    "P0020009":'naopi_alone_nh',
    "P0020010":"other_race_nh"})
df2020=pd.merge(df, df1)
df2020=df2020[df2020.SUMLEV == '040']

df2020["multi_race"]=df2020.total_pop-df2020.hisp_latino-df2020.one_race_nh
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3,9,18,27,30,57,58,77,78,86,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# df2020['other_races']=df2020.aian_alone_nh + df2020.naopi_alone_nh + df2020.other_race_nh

# %%
df2020=df2020[['total_pop',
 'hisp_latino',
 'one_race_nh',
 'white_alone_nh',
 'black_alone_nh',
 'aian_alone_nh',
 'asian_alone_nh',
 'naopi_alone_nh',
 'other_race_nh',
 'multi_race']]

# %%
df2020['year'] =2020

# %%
df_2010=pd.DataFrame([{'year':2010,"total_pop":4339367,"hisp_latino":132836,"white_alone_nh":3745655,
  "black_alone_nh":333075,"aian_alone_nh":8642,"asian_alone_nh":48338,"naopi_alone_nh":2074,"other_race_nh":4634,
                      'multi_race':64113}])
df_2010
# Out:
#    year  total_pop  hisp_latino  white_alone_nh  black_alone_nh  \
# 0  2010    4339367       132836         3745655          333075
#
#    aian_alone_nh  asian_alone_nh  naopi_alone_nh  other_race_nh  multi_race
# 0           8642           48338            2074           4634       64113

# %%
df2020=df2020[['year', 'total_pop', 'hisp_latino', 'white_alone_nh',
       'black_alone_nh', 'aian_alone_nh', 'asian_alone_nh', 'naopi_alone_nh',
       'other_race_nh', 'multi_race']]

# %%
merged_df=pd.concat([df2020,df_2010]).reset_index(drop=True)

# %%
merged_df
# Out:
#    year  total_pop  hisp_latino  white_alone_nh  black_alone_nh  \
# 0  2020    4505836       207854         3664764          357764
# 1  2010    4339367       132836         3745655          333075
#
#    aian_alone_nh  asian_alone_nh  naopi_alone_nh  other_race_nh  multi_race
# 0           8080           73843            3462          14706      175363
# 1           8642           48338            2074           4634       64113

# %%
transposed_df=merged_df.T.reset_index()

# %%
transposed_df.columns=transposed_df.iloc[0]

# %%
transposed_df=transposed_df[1:]

# %%
transposed_df=transposed_df.reset_index(drop=True)

# %%
transposed_df=transposed_df.rename(columns={"year":"race", 2020: "pop_2020", 2010:"pop_2010"})

# %%
transposed_df
# Out:
# 0            race  pop_2020  pop_2010
# 0       total_pop   4505836   4339367
# 1     hisp_latino    207854    132836
# 2  white_alone_nh   3664764   3745655
# 3  black_alone_nh    357764    333075
# 4   aian_alone_nh      8080      8642
# 5  asian_alone_nh     73843     48338
# 6  naopi_alone_nh      3462      2074
# 7   other_race_nh     14706      4634
# 8      multi_race    175363     64113

# %%
transposed_df.pop_2020=transposed_df.pop_2020.astype(float)
transposed_df.pop_2010=transposed_df.pop_2010.astype(float)

# %%
transposed_df['pct_change']=((transposed_df.pop_2020-transposed_df.pop_2010)*100/transposed_df.pop_2010).round(2)

# %%
import matplotlib.pyplot as plt

transposed_df.sort_values("pct_change").plot.barh(x="race",y='pct_change', rot=0)
plt.savefig("pop_change.svg")

# %%
merged_df[['year','white_alone_nh', 'black_alone_nh','hisp_latino', 
       'multi_race','asian_alone_nh','other_race_nh',
       'aian_alone_nh',  'naopi_alone_nh' ]].sort_values("white_alone_nh", ascending=False).set_index("year").plot.barh(stacked=True)
plt.savefig("test.svg")

# %%
transposed_df['pop_share_2020'] = transposed_df.pop_2020*100/4505836.0
transposed_df['pop_share_2010'] = transposed_df.pop_2010*100/4339367.0

transposed_df
# Out:
# 0            race   pop_2020   pop_2010  pct_change  pop_share_2020  \
# 0       total_pop  4505836.0  4339367.0        3.84      100.000000
# 1     hisp_latino   207854.0   132836.0       56.47        4.612995
# 2  white_alone_nh  3664764.0  3745655.0       -2.16       81.333719
# 3  black_alone_nh   357764.0   333075.0        7.41        7.940014
# 4   aian_alone_nh     8080.0     8642.0       -6.50        0.179323
# 5  asian_alone_nh    73843.0    48338.0       52.76        1.638830
# 6  naopi_alone_nh     3462.0     2074.0       66.92        0.076834
# 7   other_race_nh    14706.0     4634.0      217.35        0.326377
# 8      multi_race   175363.0    64113.0      173.52        3.891908
#
# 0  pop_share_2010
# 0      100.000000
# 1        3.061184
# 2       86.318004
# 3        7.675659
# 4        0.199153
# 5        1.113941
# 6        0.047795
# 7        0.106790
# 8        1.477474

# %% [markdown]
# ### Louisville Analysis

# %%
block_groups=race_final[race_final.SUMLEV == 150]

# %%
block_groups['county_fips']=block_groups.GEOCODE.astype(str).str.extract(r'(\d{5})')
# Out:
# <ipython-input-37-5c6d6212331c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_groups['county_fips']=block_groups.GEOCODE.astype(str).str.extract(r'(\d{5})')

# %%
jeff_county_bg=block_groups[block_groups.county_fips == '21111'].reset_index(drop=True)
jeff_county_bg["multi_race"]=jeff_county_bg.total_pop-jeff_county_bg.hisp_latino-jeff_county_bg.one_race_nh

# %%
jeff_county_bg=jeff_county_bg[["GEOCODE", "NAME", "total_pop", "hisp_latino", "white_alone_nh",
               "black_alone_nh", "aian_alone_nh", "asian_alone_nh", "naopi_alone_nh", "other_race_nh", "multi_race"]]

# %%
ky2010=pd.read_csv("ky2010.pl/race_2010.csv")
ky2010
# Out:
#                id                         block_group  tot_pop_2010  \
# 0    211110002001       Block Group 1, Census Tract 2           853
# 1    211110002002       Block Group 2, Census Tract 2           688
# 2    211110002003       Block Group 3, Census Tract 2          1383
# 3    211110003001       Block Group 1, Census Tract 3          1122
# 4    211110003002       Block Group 2, Census Tract 3           815
# ..            ...                                 ...           ...
# 570  211110128021  Block Group 1, Census Tract 128.02          1770
# 571  211110128022  Block Group 2, Census Tract 128.02           773
# 572  211110131001     Block Group 1, Census Tract 131          1366
# 573  211110131002     Block Group 2, Census Tract 131           700
# 574  211119801001    Block Group 1, Census Tract 9801             0
#
#      white_2010  black_2010  aian_2010  asian_2010  napi_2010  \
# 0           549         276          3           0          0
# 1           503         151          1           1          0
# 2           997         325          4           2          0
# 3           902         192          0           0          3
# 4           282         488          0           0          0
# ..          ...         ...        ...         ...        ...
# 570         527        1142          3           1          0
# 571         275         280          0           5          0
# 572        1282          16          4          23          3
# 573         670          12          0           3          0
# 574           0           0          0           0          0
#
#      other_race_2010  multi_race_2010  hisp_2010
# 0                  0               16          9
# 1                  2               21          9
# 2                  2               35         18
# 3                  0               21          4
# 4                  0               35         10
# ..               ...              ...        ...
# 570                5               48         44
# 571                4               15        194
# 572                0               12         26
# 573                0                5         10
# 574                0                0          0
#
# [575 rows x 11 columns]

# %%
jeff_county_bg['other_races']=jeff_county_bg.aian_alone_nh + jeff_county_bg.naopi_alone_nh + jeff_county_bg.other_race_nh

jeff_county_bg["pct_hisp_lat"]=(jeff_county_bg.hisp_latino*100/jeff_county_bg.total_pop).round(2)
jeff_county_bg["pct_multi_race"]=(jeff_county_bg.multi_race*100/jeff_county_bg.total_pop).round(2)
jeff_county_bg["pct_white"]=(jeff_county_bg.white_alone_nh*100/jeff_county_bg.total_pop).round(2)
jeff_county_bg["pct_black"]=(jeff_county_bg.black_alone_nh*100/jeff_county_bg.total_pop).round(2)
jeff_county_bg["pct_asian"]=(jeff_county_bg.asian_alone_nh*100/jeff_county_bg.total_pop).round(2)
jeff_county_bg["pct_other_races"]=(jeff_county_bg.other_races*100/jeff_county_bg.total_pop).round(2)

# %%
ky2010['other_races_2010']=ky2010.aian_2010 + ky2010.napi_2010 + ky2010.other_race_2010

ky2010["pct_hisp_lat"]=(ky2010.hisp_2010*100/ky2010.tot_pop_2010).round(2)
ky2010["pct_multi_race"]=(ky2010.multi_race_2010*100/ky2010.tot_pop_2010).round(2)
ky2010["pct_white"]=(ky2010.white_2010*100/ky2010.tot_pop_2010).round(2)
ky2010["pct_black"]=(ky2010.black_2010*100/ky2010.tot_pop_2010).round(2)
ky2010["pct_asian"]=(ky2010.asian_2010*100/ky2010.tot_pop_2010).round(2)
ky2010["pct_other_races"]=(ky2010.other_races_2010*100/ky2010.tot_pop_2010).round(2)

# %%
ky2010=ky2010[["id","block_group", 'pct_hisp_lat',
       'pct_multi_race', 'pct_white', 'pct_black', 'pct_asian',
       'pct_other_races']].dropna()

jeff_county_bg=jeff_county_bg[["GEOCODE","NAME", 'pct_hisp_lat',
       'pct_multi_race', 'pct_white', 'pct_black', 'pct_asian',
       'pct_other_races']].dropna()

# %%
# ky2010.to_csv("jefferson_county/jefferson_bg10.csv", index=False)
# jeff_county_bg.to_csv("jefferson_county/jefferson_bg20.csv", index=False)

# %%
block=race_final[race_final.SUMLEV == 750]
block['county_fips']=block.GEOCODE.astype(str).str.extract(r'(\d{5})')
# Out:
# <ipython-input-181-ccc6d3c8e9f6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block['county_fips']=block.GEOCODE.astype(str).str.extract(r'(\d{5})')

# %%
block=block[block.county_fips == '21111'].reset_index(drop=True)

# %%
block["pct_white"]=(block.white_alone_nh*100/block.total_pop).round(2)
block["pct_black"]=(block.black_alone_nh*100/block.total_pop).round(2)

# %%
block[["GEOCODE","NAME", 'pct_white', 'pct_black']].dropna().to_csv("block_pop_2020.csv", index=False)

# %%
#read census tract cleaned file here

df=pd.read_csv("pop_by_CT2020.csv")

# %%
df['county_fips']=df.GEOCODE.astype(str).str.extract(r'(\d{5})')

# %%
df=df[df.county_fips == '21111'].reset_index(drop=True)

# %%
df["multiracial"]=df.total_pop-df.hisp_latino-df.one_race_nh

# %%
df['pct_multiracial']=(df.multiracial*100/df.total_pop).round(2)

# %%
# df[['GEOCODE', 'NAME', 'total_pop', 
#        'hisp_latino', 'white_alone_nh',
#        'black_alone_nh', 'asian_alone_nh','multiracial', 'other_races', 'pct_hisp_lat',
#       'pct_white', 'pct_black', 'pct_asian','pct_other_races', 
#        'pct_multiracial']].to_csv("jefferson_county_2020_pop_profile.csv", index=False)

# %%
df90=pd.read_csv("demographic_profile_1990.csv")

# %%
total_pop90=pd.read_csv("total_pop_tracts_jf_1990.csv")

# %%
total_pop90=total_pop90[['GIS Join Match Code','County Name', 'State Name','Total']]

# %%
race90=pd.merge(df90, total_pop90)

# %%
race90=race90[['GIS Join Match Code', 
       'Area Name/PSAD Term/Part Indicator', 'Not of Hispanic origin >> White',
       'Not of Hispanic origin >> Black',
       'Not of Hispanic origin >> American Indian, Eskimo, or Aleut',
       'Not of Hispanic origin >> Asian or Pacific Islander',
       'Not of Hispanic origin >> Other race', 'Hispanic origin >> White',
       'Hispanic origin >> Black',
       'Hispanic origin >> American Indian, Eskimo, or Aleut',
       'Hispanic origin >> Asian or Pacific Islander', 'Total']]

# %%
race90

# 'GIS Join Match Code': "gcode_1990", 
#        'Area Name/PSAD Term/Part Indicator':"tract_name_1990", 
#         'Not of Hispanic origin >> White': "white_1990",
#        'Not of Hispanic origin >> Black': "black_1990",
#        'Not of Hispanic origin >> American Indian, Eskimo, or Aleut',
#        'Not of Hispanic origin >> Asian or Pacific Islander',
#        'Not of Hispanic origin >> Other race', 'Hispanic origin >> White',
#        'Hispanic origin >> Black',
#        'Hispanic origin >> American Indian, Eskimo, or Aleut',
#        'Hispanic origin >> Asian or Pacific Islander', 'Total'
# Out:
#     GIS Join Match Code Area Name/PSAD Term/Part Indicator  \
# 0          G21011100001                            Tract 1
# 1          G21011100002                            Tract 2
# 2          G21011100003                            Tract 3
# 3          G21011100004                            Tract 4
# 4          G21011100005                            Tract 5
# ..                  ...                                ...
# 173      G2101110012802                       Tract 128.02
# 174        G21011100129                          Tract 129
# 175        G21011100130                          Tract 130
# 176        G21011100131                          Tract 131
# 177        G21011100132                          Tract 132
#
#      Not of Hispanic origin >> White  Not of Hispanic origin >> Black  \
# 0                                826                              144
# 1                               1793                               51
# 2                                561                             1128
# 3                                851                             3667
# 4                               1491                               86
# ..                               ...                              ...
# 173                             1956                              787
# 174                              715                                4
# 175                             1542                                0
# 176                             2041                                9
# 177                              605                                3
#
#      Not of Hispanic origin >> American Indian, Eskimo, or Aleut  \
# 0                                                    3
# 1                                                    1
# 2                                                    8
# 3                                                    7
# 4                                                    5
# ..                                                 ...
# 173                                                  0
# 174                                                  9
# 175                                                  1
# 176                                                  1
# 177                                                  0
#
#      Not of Hispanic origin >> Asian or Pacific Islander  \
# 0                                                    0
# 1                                                    1
# 2                                                    0
# 3                                                    7
# 4                                                    3
# ..                                                 ...
# 173                                                  5
# 174                                                  1
# 175                                                 12
# 176                                                 18
# 177                                                  3
#
#      Not of Hispanic origin >> Other race  Hispanic origin >> White  \
# 0                                       0                         3
# 1                                       0                        12
# 2                                       0                         0
# 3                                       6                         2
# 4                                       2                        10
# ..                                    ...                       ...
# 173                                     0                         2
# 174                                     0                         0
# 175                                     0                         5
# 176                                     0                         6
# 177                                     0                         7
#
#      Hispanic origin >> Black  \
# 0                           0
# 1                           0
# 2                           4
# 3                           6
# 4                           0
# ..                        ...
# 173                         2
# 174                         0
# 175                         0
# 176                         0
# 177                         0
#
#      Hispanic origin >> American Indian, Eskimo, or Aleut  \
# 0                                                    0
# 1                                                    3
# 2                                                    0
# 3                                                    0
# 4                                                    1
# ..                                                 ...
# 173                                                  0
# 174                                                  0
# 175                                                  0
# 176                                                  0
# 177                                                  0
#
#      Hispanic origin >> Asian or Pacific Islander  Total
# 0                                               0    980
# 1                                               0   1861
# 2                                               0   1704
# 3                                               0   4547
# 4                                               0   1599
# ..                                            ...    ...
# 173                                             1   2755
# 174                                             0    729
# 175                                             0   1560
# 176                                             0   2078
# 177                                             0    618
#
# [178 rows x 12 columns]

# %%
race90['hisp_1990']=race90['Hispanic origin >> White']+race90['Hispanic origin >> Black']+race90['Hispanic origin >> American Indian, Eskimo, or Aleut']+race90['Hispanic origin >> Asian or Pacific Islander']
# Out:
# <ipython-input-47-9bdcf4471380>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   race90['hisp_1990']=race90['Hispanic origin >> White']+race90['Hispanic origin >> Black']+race90['Hispanic origin >> American Indian, Eskimo, or Aleut']+race90['Hispanic origin >> Asian or Pacific Islander']

# %%
race90['other_race_1990']=race90.Total-race90.hisp_1990-race90[
    'Not of Hispanic origin >> White']-race90['Not of Hispanic origin >> Black']-race90[
    "Not of Hispanic origin >> American Indian, Eskimo, or Aleut"
]-race90['Not of Hispanic origin >> Asian or Pacific Islander']-race90["Not of Hispanic origin >> Other race"
    
]
# Out:
# <ipython-input-50-c7d54c395610>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   race90['other_race_1990']=race90.Total-race90.hisp_1990-race90[

# %%
race90=race90.rename(columns={ 'GIS Join Match Code': "gcode_1990", 
       'Area Name/PSAD Term/Part Indicator':"tract_name_1990", 
        'Not of Hispanic origin >> White': "white_1990",
       'Not of Hispanic origin >> Black': "black_1990", 'Total':'total_pop_1990'})

# %%
race90=race90[['gcode_1990', 'tract_name_1990', 'total_pop_1990','white_1990', 'black_1990','hisp_1990']]

# %%
race90["pct_white_1990"]=(race90.white_1990*100/race90.total_pop_1990).round(2)
race90["pct_black_1990"]=(race90.black_1990*100/race90.total_pop_1990).round(2)
race90["pct_hisp_1990"]=(race90.hisp_1990*100/race90.total_pop_1990).round(2)

# %%
race90.to_csv("jefferson_demo_profile_1990.csv", index=False)

# %%
df90=pd.read_csv("jefferson_demo_profile_1990.csv")

# %%
len('2101110012802')
# Out:
# 13

# %%
len("21111000201")
# 21111012802
# Out:
# 11

# %%
df90["GEOCODE_1990"]=df90.geocode_1990.astype(str).str.replace("2101110", "21111")
# 21
# 111
# 000201
# 21 0111 0 012802

# %%
df90=df90[['gcode_1990', 'GEOCODE_1990', 'tract_name_1990', 'total_pop_1990',
       'white_1990', 'black_1990', 'hisp_1990', 'pct_white_1990',
       'pct_black_1990', 'pct_hisp_1990']]
# .to_csv("jefferson_demo_profile_1990.csv", index=False)

# %%
df90.keys()
# Out:
# Index(['gcode_1990', 'geocode_1990', 'tract_name_1990', 'total_pop_1990',
#        'white_1990', 'black_1990', 'hisp_1990', 'pct_white_1990',
#        'pct_black_1990', 'pct_hisp_1990', 'GEOCODE_1990'],
#       dtype='object')

# %%
df["GEOCODE"]=df.GEOCODE.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GEOCODE          216 non-null    object
#  1   NAME             216 non-null    object
#  2   total_pop        216 non-null    int64
#  3   one_race_pop     216 non-null    int64
#  4   multi_race       216 non-null    int64
#  5   hisp_latino      216 non-null    int64
#  6   not_hisp_latino  216 non-null    int64
#  7   one_race_nh      216 non-null    int64
#  8   white_alone_nh   216 non-null    int64
#  9   black_alone_nh   216 non-null    int64
#  10  asian_alone_nh   216 non-null    int64
#  11  other_races      216 non-null    int64
#  12  pct_hisp_lat     216 non-null    float64
#  13  pct_multi_race   216 non-null    float64
#  14  pct_whilte       216 non-null    float64
#  15  pct_black        216 non-null    float64
#  16  pct_asian        216 non-null    float64
#  17  pct_other_races  216 non-null    float64
#  18  pct_white        216 non-null    float64
#  19  county_fips      216 non-null    object
#  20  multiracial      216 non-null    int64
#  21  pct_multiracial  216 non-null    float64
#  22  GEOCODE_1990     178 non-null    object
# dtypes: float64(8), int64(11), object(4)
# memory usage: 38.9+ KB

# %%
pd.merge(df, df90, left_on="GEOCODE", right_on="GEOCODE_1990")
# Out:
#          GEOCODE                 NAME  total_pop  one_race_pop  multi_race  \
# 0    21111000300       Census Tract 3       2437          2292         145
# 1    21111000400       Census Tract 4       4360          4180         180
# 2    21111000600       Census Tract 6       1671          1602          69
# 3    21111000700       Census Tract 7       2414          2341          73
# 4    21111000800       Census Tract 8       2019          1917         102
# ..           ...                  ...        ...           ...         ...
# 115  21111012702  Census Tract 127.02       1936          1786         150
# 116  21111012703  Census Tract 127.03       5855          5439         416
# 117  21111012801  Census Tract 128.01       3185          3004         181
# 118  21111012802  Census Tract 128.02       2646          2452         194
# 119  21111013100     Census Tract 131       1183          1115          68
#
#      hisp_latino  not_hisp_latino  one_race_nh  white_alone_nh  \
# 0             50             2387         2258            1001
# 1             54             4306         4154             923
# 2             40             1631         1577              98
# 3             55             2359         2298             148
# 4             33             1986         1893             111
# ..           ...              ...          ...             ...
# 115          122             1814         1707            1304
# 116          356             5499         5185            3979
# 117           79             3106         2964             377
# 118          261             2385         2255             575
# 119           37             1146         1101            1060
#
#      black_alone_nh  ...      gcode_1990  GEOCODE_1990_y  tract_name_1990  \
# 0              1243  ...    G21011100003     21111000300          Tract 3
# 1              3193  ...    G21011100004     21111000400          Tract 4
# 2              1461  ...    G21011100006     21111000600          Tract 6
# 3              2124  ...    G21011100007     21111000700          Tract 7
# 4              1764  ...    G21011100008     21111000800          Tract 8
# ..              ...  ...             ...             ...              ...
# 115             377  ...  G2101110012702     21111012702     Tract 127.02
# 116            1129  ...  G2101110012703     21111012703     Tract 127.03
# 117            2554  ...  G2101110012801     21111012801     Tract 128.01
# 118            1631  ...  G2101110012802     21111012802     Tract 128.02
# 119              11  ...    G21011100131     21111013100        Tract 131
#
#      total_pop_1990  white_1990  black_1990  hisp_1990  pct_white_1990  \
# 0              1704         561        1128          4           32.92
# 1              4547         851        3667          8           18.72
# 2              1921         208        1707          4           10.83
# 3              3238         135        3095          1            4.17
# 4              2508         101        2382         21            4.03
# ..              ...         ...         ...        ...             ...
# 115            2452        2352          87          5           95.92
# 116            5218        4923         231         21           94.35
# 117            3758         969        2757         22           25.78
# 118            2755        1956         787          5           71.00
# 119            2078        2041           9          6           98.22
#
#      pct_black_1990 pct_hisp_1990
# 0             66.20          0.23
# 1             80.65          0.18
# 2             88.86          0.21
# 3             95.58          0.03
# 4             94.98          0.84
# ..              ...           ...
# 115            3.55          0.20
# 116            4.43          0.40
# 117           73.36          0.59
# 118           28.57          0.18
# 119            0.43          0.29
#
# [120 rows x 33 columns]

# %%
df90
# Out:
#          gcode_1990 GEOCODE_1990 tract_name_1990  total_pop_1990  white_1990  \
# 0    G2101110012802  21111012802    Tract 128.02            2755        1956
# 1    G2101110012801  21111012801    Tract 128.01            3758         969
# 2    G2101110012703  21111012703    Tract 127.03            5218        4923
# 3    G2101110012702  21111012702    Tract 127.02            2452        2352
# 4    G2101110012701  21111012701    Tract 127.01            4974        2255
# ..              ...          ...             ...             ...         ...
# 173    G21011100005  21111000500         Tract 5            1599        1491
# 174    G21011100004  21111000400         Tract 4            4547         851
# 175    G21011100003  21111000300         Tract 3            1704         561
# 176    G21011100002  21111000200         Tract 2            1861        1793
# 177    G21011100001  21111000100         Tract 1             980         826
#
#      black_1990  hisp_1990  pct_white_1990  pct_black_1990  pct_hisp_1990
# 0           787          5           71.00           28.57           0.18
# 1          2757         22           25.78           73.36           0.59
# 2           231         21           94.35            4.43           0.40
# 3            87          5           95.92            3.55           0.20
# 4          2677         12           45.34           53.82           0.24
# ..          ...        ...             ...             ...            ...
# 173          86         11           93.25            5.38           0.69
# 174        3667          8           18.72           80.65           0.18
# 175        1128          4           32.92           66.20           0.23
# 176          51         15           96.35            2.74           0.81
# 177         144          3           84.29           14.69           0.31
#
# [178 rows x 10 columns]

# %%
df
# Out:
#          GEOCODE                 NAME  total_pop  one_race_pop  multi_race  \
# 0    21111000201    Census Tract 2.01       1392          1307          85
# 1    21111000202    Census Tract 2.02       1141          1100          41
# 2    21111000300       Census Tract 3       2437          2292         145
# 3    21111000400       Census Tract 4       4360          4180         180
# 4    21111000600       Census Tract 6       1671          1602          69
# ..           ...                  ...        ...           ...         ...
# 211  21111012703  Census Tract 127.03       5855          5439         416
# 212  21111012801  Census Tract 128.01       3185          3004         181
# 213  21111012802  Census Tract 128.02       2646          2452         194
# 214  21111013100     Census Tract 131       1183          1115          68
# 215  21111980100    Census Tract 9801         14             8           6
#
#      hisp_latino  not_hisp_latino  one_race_nh  white_alone_nh  \
# 0             36             1356         1291             854
# 1              7             1134         1095             794
# 2             50             2387         2258            1001
# 3             54             4306         4154             923
# 4             40             1631         1577              98
# ..           ...              ...          ...             ...
# 211          356             5499         5185            3979
# 212           79             3106         2964             377
# 213          261             2385         2255             575
# 214           37             1146         1101            1060
# 215            1               13            8               7
#
#      black_alone_nh  ...  pct_multi_race  pct_whilte  pct_black  pct_asian  \
# 0               415  ...            6.11       61.35      29.81       0.14
# 1               288  ...            3.59       69.59      25.24       0.09
# 2              1243  ...            5.95       41.08      51.01       0.12
# 3              3193  ...            4.13       21.17      73.23       0.00
# 4              1461  ...            4.13        5.86      87.43       0.12
# ..              ...  ...             ...         ...        ...        ...
# 211            1129  ...            7.11       67.96      19.28       0.72
# 212            2554  ...            5.68       11.84      80.19       0.35
# 213            1631  ...            7.33       21.73      61.64       0.72
# 214              11  ...            5.75       89.60       0.93       1.27
# 215               1  ...           42.86       50.00       7.14       0.00
#
#      pct_other_races  pct_white  county_fips  multiracial  pct_multiracial  \
# 0               1.44      61.35        21111           65             4.67
# 1               1.05      69.59        21111           39             3.42
# 2               0.45      41.08        21111          129             5.29
# 3               0.87      21.17        21111          152             3.49
# 4               0.96       5.86        21111           54             3.23
# ..               ...        ...          ...          ...              ...
# 211             0.60      67.96        21111          314             5.36
# 212             0.69      11.84        21111          142             4.46
# 213             1.13      21.73        21111          130             4.91
# 214             1.27      89.60        21111           45             3.80
# 215             0.00      50.00        21111            5            35.71
#
#     GEOCODE_1990
# 0    21111012802
# 1    21111012801
# 2    21111012703
# 3    21111012702
# 4    21111012701
# ..           ...
# 211          NaN
# 212          NaN
# 213          NaN
# 214          NaN
# 215          NaN
#
# [216 rows x 23 columns]

# %% [markdown]
# ## Block analysis

# %%
block=race_final[race_final.SUMLEV == 750]
block['county_fips']=block.GEOCODE.astype(str).str.extract(r'(\d{5})')
block=block[block.county_fips == '21111'].reset_index(drop=True)
# Out:
# <ipython-input-26-8f553d562b22>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block['county_fips']=block.GEOCODE.astype(str).str.extract(r'(\d{5})')

# %%
block["multi_race"]=block.total_pop-block.hisp_latino-block.one_race_nh
block['other_races']=block.aian_alone_nh + block.naopi_alone_nh + block.other_race_nh +block.asian_alone_nh

block["pct_hisp_lat"]=(block.hisp_latino*100/block.total_pop).round(2)
block["pct_multi_race"]=(block.multi_race*100/block.total_pop).round(2)
block["pct_white"]=(block.white_alone_nh*100/block.total_pop).round(2)
block["pct_black"]=(block.black_alone_nh*100/block.total_pop).round(2)
# block["pct_asian"]=(block.asian_alone_nh*100/block.total_pop).round(2)
block["pct_other_races"]=(block.other_races*100/block.total_pop).round(2)

# %%
block[['GEOCODE', 'NAME','total_pop', 'hisp_latino', 'white_alone_nh', 'black_alone_nh', 
       'other_races', 'pct_hisp_lat',
       'pct_white', 'pct_black', 'pct_other_races']].to_csv("jefferson_2020block_pop.csv", index=False)
